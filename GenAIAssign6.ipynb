# %% [markdown]
# <a href="https://colab.research.google.com/github/Prafull009/GenAI/blob/main/GenAIAssign6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio diffusers transformers accelerate safetensors Pillow

# %%
import torch
from diffusers import DiffusionPipeline
from PIL import Image
import IPython.display as display

# %%
pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5").to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# text_encoder%2Fconfig.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# safety_checker%2Fconfig.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# (…)ure_extractor%2Fpreprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer%2Fspecial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer%2Fmerges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler%2Fscheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# tokenizer%2Ftokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# ...

# %%
print("Enter text to generate image(Enter 'Exit' to end conversation):\n")
while True:
  prompt = input("You: ")
  if prompt.lower() == "exit": break
  image = pipeline(prompt, guidance_scale = 7.5).images[0]
  image.show()
  display.display(image)
  image.save("prompt.png")
# Out:
# Enter text to generate image(Enter 'Exit' to end conversation):
#
# You: venice city
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# You: exit
